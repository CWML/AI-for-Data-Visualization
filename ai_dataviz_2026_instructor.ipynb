# %% [markdown]
# # Using AI for Visualization
# **Yale Medical Library · 2-Hour Hands-On Workshop**
#
# In this workshop you'll use **seaborn** — Python's most approachable statistical graphics library — as your charting engine, and an **AI coding assistant** as your first-draft generator. The central skill is a loop you'll use for the rest of your data work:
#
# **describe → generate → run → read the output or error → refine.**
#
# - **seaborn** speaks directly to pandas DataFrames. Hand it a tidy table, map columns to visual properties, and get a polished figure in one line. If you've ever used a plotting library in any language you'll find the mental model familiar — but no prior plotting experience is required.
# - We use the data that ships **inside seaborn** — no files to upload.
# - And we point an **AI coding assistant** at the plotting workflow. **Use whatever AI you already have** — ChatGPT, Claude, Copilot — or **Gemini, built right into Google Colab** (nothing to install). The skill is the loop and the critical eye, not the brand.
#
# > **The rule for today: _AI drafts, you direct._** The assistant writes the code fast; *you* decide whether the figure is clear, honest, and makes the point. A misleading chart doesn't just look bad — it misinforms. So the last thing we practice is **verifying** what the AI hands you.
#
# Here's the through-line: **§1–§3 build the *eye*** — enough seaborn to recognize a good plot and name what you want — and **§4–§5 put an AI to work** drafting plots while you direct and verify them. **§6** gives you time to apply everything to a chart that matters to your own work. The seaborn you learn first is exactly what lets you catch the AI when it's wrong.
#
# Run the setup cell next.

# %% [markdown]
# > 🎤 **Instructor**
# >
# > ~2 min. A short slide deck (`slides/ai-for-dataviz-intro.md`) sets up the concepts before you open this notebook — don't re-read the intro aloud; just land the one rule: "AI drafts, you direct." Quick check-in: who has used a plotting library before, in any language? Who has used an AI coding assistant? Anchor to both — we build on what they know, we don't start from scratch. Students are on the STUDENT notebook (blank cells); you're driving this one.

# %% [markdown]
# ## ⚙️ Setup — run this cell first

# %% [markdown]
# > 🎤 **Instructor**
# >
# > ~2 min, but do it FIRST and confirm everyone is green before you teach.
# > This is the moment to surface AI access: ask everyone to open Colab and check they
# > see the Gemini ✨ / "+ Generate" affordance, OR have a ChatGPT/Claude tab ready.
# > Note the no-AI safety net (worked answers) so nobody panics. If Colab sign-in is
# > slow, keep talking through §1 while it loads.

# %%
# ===== SETUP — run this cell first! =====
import seaborn as sns
import matplotlib.pyplot as plt

# One line that makes EVERY plot look professional:
sns.set_theme(style="whitegrid", context="talk")

# seaborn ships with clean datasets — no files needed:
penguins = sns.load_dataset("penguins").dropna()
tips     = sns.load_dataset("tips")
flights  = sns.load_dataset("flights")
titanic  = sns.load_dataset("titanic")

print("Datasets loaded:")
for name, df in [("penguins", penguins), ("tips", tips),
                 ("flights", flights), ("titanic", titanic)]:
    print(f"  {name:9s} {df.shape}  ->  {list(df.columns)}")

penguins.head()

# %% [markdown]
# ---
# # 1. Why seaborn? (~8 min)
#
# Think of it this way: **matplotlib is the engine; seaborn is the smart layer on top.** Seaborn talks to pandas DataFrames directly, does the statistics for you, and looks good by default. It still *returns* matplotlib objects, so you can fine-tune anything with `plt.title`, `figsize`, `plt.savefig`.
#
# The underlying idea is called the **grammar of graphics**: map a DataFrame column to a visual property (x-position, y-position, color, size, shape), and the chart builds itself. Seaborn uses that idea in Python — `hue=` colors by a column, `col=` splits into faceted panels, and so on. If you've plotted in any other library or language, you'll recognize this pattern. If not, you'll pick it up in the next few sections. (For the curious: R's ggplot2 uses the same grammar — `aes(color=)` is `hue=`, `facet_wrap` is `col=` — so seaborn will feel familiar to R users too.)
#
# The "aha": this single line **groups by day, averages the bill, AND draws error bars** — all in one call:

# %% [markdown]
# > 🎤 **Instructor**
# >
# > ~8 min. The takeaway is "one line does the grouping + stats + drawing."
# > Run the barplot, point at the error bars, say "that's a stat_summary layer for
# > free." Don't dwell — they don't need to master barplot, they need to believe
# > seaborn is terse and smart so that asking an AI for it is reasonable.

# %%
sns.barplot(data=tips, x="day", y="total_bill")
plt.title("Average bill by day")
plt.show()

# %% [markdown]
# **You write the *what*, not the *how*.** You name the DataFrame and which
# columns go on x and y — seaborn handles the rest.
#
# > 💬 **With AI:** you'll rarely type these from scratch — in §4 you'll just *ask*
# > for them. So why learn seaborn at all? Because "you write the *what*" is also how
# > you **prompt**, and recognizing a correct plot is how you **catch a wrong one**.
# > §1–§3 build that eye.

# %% [markdown]
# ---
# # 2. The three families of plots (~22 min)
#
# Almost every seaborn plot belongs to one of three families, each answering a
# different kind of question:
#
# | Your question | Family | Functions |
# |---|---|---|
# | "How do two **numbers** relate?" | **Relational** | `scatterplot`, `lineplot` |
# | "What's the **shape/spread** of a number?" | **Distribution** | `histplot`, `boxplot` |
# | "How does a number **compare across categories**?" | **Categorical** | `barplot`, `countplot` |
#
# Pick the family that matches your question — that's visualization principle #1.
#
# > 💬 **With AI:** these three words — *relational, distribution, categorical* — are
# > the most useful thing you can put in a prompt. "Show the **distribution** of body
# > mass" gets you a far better first draft than "plot body mass," and it's how you
# > sanity-check what comes back: *does the chart type match the question?*

# %% [markdown]
# > 🎤 **Instructor**
# >
# > ~22 min total for §2. Run the five examples briskly (~2 min each), naming
# > the family each time. Keep narrating the question→family mapping — that table is
# > the spine of the whole session. Leave ~3–4 min for the "Your turn" below: let them
# > type it, circulate, then show your answer on the projector.

# %% [markdown]
# ### Relational — `scatterplot`: how do two numbers relate?

# %%
sns.scatterplot(data=penguins, x="bill_length_mm", y="flipper_length_mm")
plt.title("Bill length vs. flipper length")
plt.show()

# %% [markdown]
# ### Relational — `lineplot`: a trend over time (flights data)

# %%
sns.lineplot(data=flights, x="year", y="passengers")
plt.title("Air passengers over time")
plt.show()

# %% [markdown]
# ### Distribution — `histplot`: the shape/spread of one number

# %%
sns.histplot(data=penguins, x="body_mass_g", bins=20)
plt.title("Distribution of penguin body mass")
plt.show()

# %% [markdown]
# ### Distribution — `boxplot`: spread of a number across categories

# %%
sns.boxplot(data=penguins, x="species", y="body_mass_g")
plt.title("Body mass by species")
plt.show()

# %% [markdown]
# ### Categorical — `countplot`: how many rows in each category?

# %%
sns.countplot(data=titanic, x="class")
plt.title("Number of passengers by class")
plt.show()

# %% [markdown]
# > 🎤 **Instructor**
# >
# > "Your turn" — this is their first time typing. Give a real 3 minutes,
# > walk the room, look for `data=tips, x="day", y="tip"`. Common slip: forgetting
# > quotes around column names. Then reveal the answer (it's the barplot from §1 with
# > columns swapped) — reinforce that recognizing the pattern is the whole point.

# %% [markdown]
# > 🗣️ **Your turn (try it):** In the blank cell below, make a `barplot` of the
# > average **tip** by **day** from the `tips` data. (Hint: copy the bar example
# > from section 1 and change the columns.)

# %%
# Your turn — average tip by day:

# %% [markdown]
# ---
# # 3. Semantic mappings — seaborn's superpower (~12 min)
#
# You can map a **column** to a **visual property** — the grammar-of-graphics idea at the heart of seaborn. This lets one plot show many variables at once. The key keywords:
#
# - `hue=`  → **color** by a column
# - `size=` → **dot/line size** by a column
# - `style=` → **marker shape** by a column
# - `col=` / `row=` → split into **separate side-by-side panels** (called facets)
#
# Watch what `hue="species"` does to our earlier scatter — the three species separate into clear clouds:

# %% [markdown]
# > 🎤 **Instructor**
# >
# > ~12 min. The first hue cell is the payoff — run it, let the species
# > clouds land. The next three (size+style, relplot, pairplot) are FAST and
# > watch-only; say so out loud so nobody falls behind typing. The real point of §3 is
# > the prompt vocabulary callout at the end — make sure you land that before §4.

# %%
sns.scatterplot(data=penguins, x="bill_length_mm", y="flipper_length_mm",
                hue="species")
plt.title("Penguin species separate cleanly by bill & flipper")
plt.show()

# %% [markdown]
# > 👀 **Demo — watch, don't type.** The next three cells go fast; just follow
# > along. You can come back and run them yourself afterward.
#
# Layer in **two more variables** at once — `size` and `style`:

# %%
sns.scatterplot(data=penguins, x="bill_length_mm", y="flipper_length_mm",
                hue="species", size="body_mass_g", style="sex")
plt.title("Four variables in one figure")
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left")
plt.show()

# %% [markdown]
# **Small multiples** with `col=` splits the data into one panel per category — each panel (or *facet*) shows the same plot for a different slice of the data. Note `relplot` is a **figure-level** function: it makes its *own* figure, so you style it via the returned grid, not a trailing `plt.title()`. (Same goes for `pairplot` and `catplot`.)

# %%
sns.relplot(data=penguins, x="bill_length_mm", y="flipper_length_mm",
            hue="species", col="island")
plt.show()

# %% [markdown]
# **`pairplot`** — instant overview: every numeric variable plotted against
# every other. Great first look at any new dataset.

# %%
sns.pairplot(penguins, hue="species")
plt.show()

# %% [markdown]
# > 💬 **With AI:** these keywords *are* your prompt vocabulary. "Color by
# > species, one panel per island, size the dots by body mass" maps straight onto
# > `hue="species", col="island", size="body_mass_g"`. The clearer your mental model
# > of what maps to what, the better the AI's first draft — and the faster you spot
# > when it mapped the wrong column.

# %% [markdown]
# ---
# # 4. ★ Main hands-on: drive an AI coding assistant (~32 min)
#
# This is the core of the workshop. You don't have to memorize seaborn — **describe what you want, let the assistant draft the code, then run, read, and improve it.**
#
# ### The describe → generate → run → read → refine loop
# It's the same loop whether the assistant is Claude, ChatGPT, Copilot, or Gemini — what makes *you* effective is a clear request and a critical eye on what comes back.
#
# > **Use whatever AI you already have.** Got ChatGPT or Claude open in a browser tab? Use that — paste the prompt, copy the code back into a cell. No account handy? **Gemini is built right into Colab** (no separate login). Pick one and go; the prompts below work the same in any of them.
#
# ### Using Gemini inside Colab (one convenient option)
# - Click **+ Generate** (or the Gemini ✨ icon) above a cell to describe a plot in  plain English and get a code cell back.
# - Select an existing code cell and ask Gemini to **improve / explain** it.
# - If a cell errors, click **"Explain error"** — Gemini tells you what went wrong.
#
# *Using ChatGPT/Claude in a browser tab instead?* Same idea — paste the prompt, copy the code into a cell, and paste any error back to ask for a fix.
#
# > **Don't see Gemini and don't have another AI handy?** No problem — every exercise below includes a worked answer you can expand and run, so you're never stuck waiting.
#
# ### A good visualization prompt has four parts
# 1. **Dataset & columns** — name the DataFrame and the columns to use.
# 2. **Goal** — the question / the takeaway.
# 3. **Constraints** — "use seaborn", colorblind-safe, one figure, add a title.
# 4. **Chart type** (optional) — if you already know it, say so.
#
# ### Copy this prompt into your AI
# ```
# Using the pandas DataFrame `penguins` (columns: species, island,
# bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex),
# use seaborn to plot body_mass_g for each species as a boxplot, colored
# by sex, with a colorblind-safe palette and a clear title. Return only code.
# ```

# %% [markdown]
# > 🎤 **Instructor**
# >
# > ~32 min — the heart of the session; protect this time, don't let §2/§3
# > overrun into it. Demo ONE full loop live on the projector first: paste the prompt
# > into Gemini, run, read, refine — narrate every step. THEN turn them loose on
# > Exercises A–D and circulate. Emphasize the four-part prompt structure; weak prompts
# > are the #1 reason their first draft is bad. Keep an eye on the clock: it's fine if
# > strong students reach C/D while others finish A/B.

# %% [markdown]
# **Paste the AI's code below and run it.** Did it work first try? If it errors, use *Explain error* (or paste the error back to your AI) and try again.

# %%
# Paste the AI's generated code here, then run:

# %% [markdown]
# > 👉 **Stuck / no AI?** Expand-and-run this worked answer (try the prompt first):

# %%
# Worked answer for the boxplot prompt above:
sns.boxplot(data=penguins, x="species", y="body_mass_g", hue="sex",
            palette="colorblind")
plt.title("Body mass by species and sex")
plt.xlabel("Species"); plt.ylabel("Body mass (g)")
plt.show()

# %% [markdown]
# ### Exercise A — ask the AI for a brand-new plot
# Pick one question, turn it into a 4-part prompt, and paste the code it gives back:
# - *"Average tip by day of week, split by lunch vs. dinner."* (`tips`)
# - *"Survival rate by passenger class."* (`titanic`)
# - *"Passengers per month across years as a heatmap."* (`flights`, needs a pivot)
# - *"How tip relates to total bill, colored by whether the party smoked."* (`tips`)
# - *"Distribution of penguin body mass for each species, as overlapping curves."* (`penguins`)

# %%
# Your AI-built plot here:

# %% [markdown]
# > 👉 **Stuck / no AI?** A worked answer for the survival-rate option:

# %%
# Survival rate by passenger class (titanic):
sns.barplot(data=titanic, x="class", y="survived", palette="colorblind")
plt.title("First-class passengers survived at the highest rate")
plt.xlabel("Passenger class"); plt.ylabel("Survival rate")
plt.show()

# %% [markdown]
# ### Exercise B — "make it better"
# Here's a working-but-ugly plot. Select it in Colab (or copy it into your AI) and ask:
# > *"Make this chart presentation-ready: clean theme, colorblind-safe palette, a
# > title that states the takeaway, labeled axes with units, bigger fonts."*
#
# Then paste the improved version in the next cell and compare.

# %% [markdown]
# > 🎤 **Instructor**
# >
# > Exercise B is the easiest "wow": the before→after jump sells why
# > directing the AI (not just accepting draft #1) matters. If short on time, this is
# > the one exercise to do together rather than skip.

# %%
# BEFORE (works, but bland):
sns.scatterplot(data=penguins, x="bill_length_mm", y="body_mass_g", hue="species")
plt.show()

# %%
# AFTER — paste the AI's improved version here:

# %% [markdown]
# > 👉 **Stuck / no AI?** One presentation-ready version of the plot above:

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.scatterplot(data=penguins, x="bill_length_mm", y="body_mass_g",
                hue="species", palette="colorblind", s=70, alpha=0.8, ax=ax)
ax.set_title("Bigger bills track with heavier penguins", weight="bold")
ax.set_xlabel("Bill length (mm)"); ax.set_ylabel("Body mass (g)")
ax.legend(title="Species")
plt.show()

# %% [markdown]
# ### Exercise C — make the AI go *further* (stretch)
# So far the AI has *drafted* and *prettied up* plots. It can also help you find the
# *right* chart and add insight you'd otherwise hand-code. If you have time, try one:
#
# - **AI as advisor:** *"I want to show how penguin body mass differs across the three
#   species. What chart type best shows this, and why? Then give me the seaborn code."*
# - **Add a trend line:** *"Add a regression/trend line to a seaborn scatter of
#   bill_length_mm vs. body_mass_g in the `penguins` data."*
# - **Annotate the takeaway:** *"Make a seaborn barplot of survival rate by class
#   (`titanic`) and print the value on top of each bar."*
#
# Notice the AI isn't just typing for you — it's helping you *decide* and *add
# meaning*. You still judge whether its advice is right.

# %%
# Your "go further" plot here:

# %% [markdown]
# > 👉 **Stuck / no AI?** A worked answer for the *annotate the takeaway* option:

# %%
ax = sns.barplot(data=titanic, x="class", y="survived", palette="colorblind")
ax.bar_label(ax.containers[0], fmt="%.2f")          # value on top of each bar
ax.set_title("First-class passengers survived at the highest rate")
ax.set_xlabel("Passenger class"); ax.set_ylabel("Survival rate")
plt.show()

# %% [markdown]
# ### Exercise D — catch the hallucination
# AI doesn't usually fail with obvious gibberish. The dangerous failures are
# **plausible** — it borrows a feature from a *different* library and writes code
# that looks completely reasonable. The cell below is exactly that: the AI tried to
# add a trend line with `trendline="ols"` — that's a **Plotly** argument; seaborn's
# `scatterplot` has no such option, so it errors.
#
# Your job, not the AI's: run it as-is, read the error (try *Explain error*), and
# **fix it in the next cell** — the *real* seaborn way to get a trend line is
# `sns.regplot`. (Worth knowing: an even sneakier hallucination is code that *runs*
# but quietly plots the wrong thing — that's why §5 is all about verifying.)

# %% [markdown]
# > 🎤 **Instructor**
# >
# > Exercise D is the message of the whole workshop in one cell. Run the
# > broken cell live, read the traceback together, click "Explain error" to show the AI
# > diagnosing its own mistake. Land the line: "the scary failures aren't crashes —
# > they're the plausible-but-wrong ones that run fine." That sets up §5.

# %%
# RUN THIS — it will error on purpose (trendline= is not a seaborn argument):
sns.scatterplot(data=penguins, x="bill_length_mm", y="body_mass_g", trendline="ols")
plt.title("Bill length vs. body mass")
plt.show()

# %% [markdown]
# **Your fix below** — get a real trend line with `sns.regplot`, and add honest labels:

# %%
# Fix the broken call above:

# %% [markdown]
# > 👉 Worked answer:

# %%
sns.regplot(data=penguins, x="bill_length_mm", y="body_mass_g",
            scatter_kws={"alpha": 0.6})
plt.title("Heavier penguins tend to have longer bills")
plt.xlabel("Bill length (mm)"); plt.ylabel("Body mass (g)")
plt.show()

# %% [markdown]
# ---
# # 5. Polish, principles & verification (~15 min)
#
# A plot that *runs* is not the same as a plot that's *ready to present*. Five
# principles, each a small seaborn choice:
#
# 1. **Right chart** → pick the matching family (you did this in §2).
# 2. **Reduce clutter** → `sns.set_theme(style="whitegrid")` (already on).
# 3. **Color with intent** → `palette="colorblind"`; use `hue` for real categories.
# 4. **Label to stand alone** → a *takeaway* title, axis labels **with units**.
# 5. **Don't mislead** → honest axes and aggregation.
#
# Here's the same penguin scatter, polished and exported for slides:

# %% [markdown]
# > 🎤 **Instructor**
# >
# > ~13 min — don't let this get squeezed; it's the payoff. Tie each
# > principle back to "would this mislead someone?" The polished export cell is a nice
# > artifact (saves a PNG for their slides). But the real close is the checklist + then
# > the groupby verify: the chart SAYS Gentoo is heaviest, the numbers CONFIRM it. End
# > on: "verify before you trust — especially when an AI wrote it."

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.scatterplot(data=penguins, x="bill_length_mm", y="body_mass_g",
                hue="species", palette="colorblind", s=60, alpha=0.8, ax=ax)
ax.set_title("Gentoo penguins are the largest by body mass", weight="bold")
ax.set_xlabel("Bill length (mm)")
ax.set_ylabel("Body mass (g)")
ax.legend(title="Species")
fig.savefig("penguins_polished.png", dpi=200, bbox_inches="tight")
plt.show()
print("Saved penguins_polished.png — drop it into your slides or report.")

# %% [markdown]
# ### ✅ Trust-this-figure checklist (before you believe any AI plot)
# - [ ] The code runs and uses **real** seaborn functions/arguments (no `trendline=`
#       borrowed from another library).
# - [ ] The **chart type matches the question** (right family).
# - [ ] **Axes, units, and the title** are correct and honest.
# - [ ] The **numbers match the data** — spot-check one value.
# - [ ] A stranger could read it **without you explaining it**.
#
# Quick verify — does the figure's story match the raw numbers?

# %%
print(penguins.groupby("species")["body_mass_g"].mean().round(0))

# %% [markdown]
# > 🎤 **Instructor**
# >
# > ~1 min wrap. The one thing to repeat on the way out: "AI drafts, you
# > direct — and you verify." Point them at README resources and the prompt-library
# > habit. Done.

# %% [markdown]
# ---
# # 6. ★ Bring your own question (~25 min)
#
# You've seen the full loop — now apply it to something that matters to **your work or research**. This is open time: pick a dataset you care about, a chart you've been meaning to make, or a figure from a paper you want to recreate or improve.
#
# **If you don't have your own data handy**, pick any of the built-in datasets (`penguins`, `tips`, `flights`, `titanic`) and design a chart that tells a story you haven't made yet. Some starting points:
# - *"How does survival on the Titanic break down across both class and sex?"* (`titanic`, try a grouped barplot or a heatmap)
# - *"Which routes (month + year combinations) had the sharpest passenger growth?"* (`flights`, pivot then `heatmap`)
# - *"Is the relationship between bill length and depth the same for all three penguin species?"* (`penguins`, faceted scatter)
#
# **Bringing your own data?** Upload a CSV or Excel file to Colab (`Files → Upload`) and load it with:
# ```python
# import pandas as pd
# df = pd.read_csv("your_file.csv")
# df.head()
# ```
# Then run the 4-part prompt pattern with your own column names.
#
# ### Goal for this section
# 1. Write a 4-part prompt for a chart that answers a real question.
# 2. Paste the AI's code, run it, and iterate until it's correct.
# 3. Polish it: takeaway title, labeled axes with units, colorblind-safe palette.
# 4. Verify: spot-check one value from the chart against the raw numbers.

# %% [markdown]
# > 🎤 **Instructor**
# >
# > ~25 min. This is open work time — circulate and help. Common issues: wrong column name (fix with `df.columns`), wrong chart type for the question (redirect using the §2 family table), or AI-hallucinated arguments (point to Exercise D as the template for fixing). If anyone finishes early, push them to the verification step — "spot check one number against the raw data." At ~5 min remaining, bring the group back to share one chart each.

# %%
# Student chart here — paste AI-generated code, run and refine:

# %% [markdown]
# **Verify your chart** — spot-check one value from the figure against the raw numbers. If your chart shows an average, compute that average and make sure the bar/point matches:
#
# ```python
# # Example pattern — adapt to your own data and question:
# # df.groupby("your_category")["your_numeric_column"].mean().round(1)
# ```

# %%
# Verify one number from your chart against the raw data:

# %% [markdown]
# ---
# ## Where to go from here
# - The seaborn tutorial is the best next read: https://seaborn.pydata.org/tutorial.html
# - For choosing the right chart: https://www.data-to-viz.com/
# - For colorblind-safe palettes: https://colorbrewer2.org/
# - See the `README.md` for the full resource list.
# - Keep a personal **prompt library** of the viz prompts that worked for you — paste what worked, note what didn't.
#
# 🎉 **Nice work!** You used seaborn for real plots, drove an AI assistant to draft and improve them, and learned to verify before you trust.
